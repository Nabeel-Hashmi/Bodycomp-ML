# %%
import pandas as pd

# Load your CSV
df = pd.read_csv("bodyfat_labels_filled.csv")
df2= pd.read_csv("bodyfat_labels_filled_augmented.csv")

# Preview
df.head()
# Out:
#         filename label_bucket  class_id              notes  Unnamed: 4
# 0  1r2tma4_1.jpg         5-10         1                NaN         NaN
# 1  1r36700_1.jpg        20-25         4                NaN         NaN
# 2  1r36700_2.jpg        20-25         4                NaN         NaN
# 3  1r3azi8_1.jpg        10-15         2  on the higher end         NaN
# 4  1r3d493_1.jpg        10-15         2          lower end         NaN

# %%
df["label_bucket"].value_counts().sort_index()
# Out:
# label_bucket
# 0-5       2
# 10-15    21
# 15-20    31
# 20-25    42
# 25-30    12
# 30+      12
# 5-10      7
# Name: count, dtype: int64

# %%
df2["label_bucket"].value_counts().sort_index()
# Out:
# label_bucket
# 0-5       4
# 10-15    42
# 15-20    62
# 20-25    42
# 25-30    24
# 30+      24
# 5-10     14
# Name: count, dtype: int64
